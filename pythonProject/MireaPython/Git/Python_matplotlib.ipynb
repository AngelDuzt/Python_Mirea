# %% [markdown]
# 1. Построить двумерный график на основе следующих уравнений:

# %%
import matplotlib.pyplot as plt
import numpy as np
x_array = []
y_array = []
t = 0.0
#t = np.linspace(0, 2 * np.pi, 100)
while t < 2 * np.pi:
    x_array.append(16 * np.sin(t) ** 3)
    y_array.append(13 * np.cos(t) - 5 * np.cos(2 * t) - 2 * np.cos(3 * t) - np.cos(4 * t))
    t += 0.1

plt.figsize = (6, 6)
plt.plot(x_array, y_array, color = 'red')

# %%
plt.fill(x_array, y_array)

# %% [markdown]
# 2. Построить трехмерный график

# %%
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D
import numpy as np

def draw(figure_func, bbox=(-1.3,1.3)):
    xmin, xmax, ymin, ymax, zmin, zmax = bbox * 3
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    a = np.linspace(xmin, xmax, 80)
    b = np.linspace(xmin, xmax, 40)
    a1, a2 = np.meshgrid(a, a)
    for x in b:
        y, z = a1, a2
        X = figure_func(x, y, z)
        cest = ax.contour(X + x, y, z, [x], zdir = 'x', colors = ('red'))
    for y in b:
        x, z = a1, a2
        Y = figure_func(x, y, z)
        cest = ax.contour(x, Y + y, z, [y], zdir = 'y', colors = ('red'))
    for z in b:
        x, y = a1, a2
        Z = figure_func(x, y, z)
        cest = ax.contour(x, y, Z + z, [z], zdir = 'z', colors = ('red'))

    plt.figsize = (10, 10)
        
    ax.set_xlim3d(xmin, xmax)
    ax.set_ylim3d(ymin, ymax)
    ax.set_zlim3d(zmin, zmax)
    plt.show()
    
def func(x, y, z):
    return (x ** 2 + 9 * y ** 2 / 4 + z ** 2 - 1) ** 3 - x ** 2 * z ** 3 - 9 * y ** 2 * z ** 3 / 200
    
draw(figure_func = func)
# Out:
# C:\Users\dasda\AppData\Local\Temp\ipykernel_13604\68070175.py:16: UserWarning: No contour levels were found within the data range.
#   cest = ax.contour(X + x, y, z, [x], zdir = 'x', colors = ('red'))
# C:\Users\dasda\AppData\Local\Temp\ipykernel_13604\68070175.py:20: UserWarning: No contour levels were found within the data range.
#   cest = ax.contour(x, Y + y, z, [y], zdir = 'y', colors = ('red'))
# C:\Users\dasda\AppData\Local\Temp\ipykernel_13604\68070175.py:24: UserWarning: No contour levels were found within the data range.
#   cest = ax.contour(x, y, Z + z, [z], zdir = 'z', colors = ('red'))

# %%
import math


def noise(x, y):
    return fract(np.sin(x * 12.9898 + y * 78.233) * 43758.5453123)

def fract(x):
    return x - math.floor(x)

y_array = []
x_array = []

for x in range (0, 1000, 1):
    x_array.append(x)
    y_array.append(noise(x, x))
figure = plt.figure()
plt.figsize = (18, 6)

plt.plot(x_array, y_array)
